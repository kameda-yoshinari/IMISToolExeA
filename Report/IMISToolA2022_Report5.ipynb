# %% [markdown]
# <a href="https://colab.research.google.com/github/kameda-yoshinari/IMISToolExeA2022/blob/main/Report/IMISToolA2022_Report5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Report 5 (2022/08/08 ver.A)
#
# for Tools for intelligent interaction systems a (0ALE005 / 0AL5706).
#
# ---
#
# <font color="red">
# If Ver.B or later, change log should be found at the end of this page.
#
# Your ID info should be placed in the following three items (MANDATORY).
# </font>
#
# * Student ID: (E.g. 202099998)...Erase-and-put-yours-here
# * Name: (E.g. 筑波 太郎）...Erase-and-put-yours-here
# * Colab account: (E.g. tsukuba.taro.xs@alumni.tsukuba.ac.jp)...Erase-and-put-yours-here
#
# ---
#
# Report could be written in English or Japanese. / レポートの記述は日本語でも英語でもよい．
#
# ---

# %% [markdown]
# ---
# # Report5A: Investigation of Deep Learning
#
# Investigate the results in section 2.8 and 3.8 as shown below.
#
# (1) Show the number of training data and validation data respectively.  Tell the way to know the number.
#
# (2) Discuss the recognition result by showing the appropriate score shown in the result.
#
# (3) Show the two good examples and two bad examples on vaidation dataset. Discuss the reason from your viewpoint.

# %%
print ('You can put many code cells and text cells around here.')
# Out:
# You can put code cells and text cells around here.

# %% [markdown]
# To put an image, the easiest way is to paste the graph (as bitmap) here when it is small.
# It is good to prepare one text cell for one image.
# Make sure **the image should be very small**.
# (Or, put the image on your google drive and share the URL.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# # Report5B: Difference of Transfer Learning and Fine Tuning
#
# Suppose you want to deliver a new object (=target) recognition on images. You can assume generic object recognition engine is there, but unfortunately the target object class is not included.
#
# (A) What is the typcal difference between Transfer Learning and Normal Learning method?
#
# (B) What is the the unique features of Fine Tuning?
#
# (C) Imagine your own case of adding a new object recognition. Discuss which should be the better choice in that case. The discussion should include the findings in (A) and (B).

# %% [markdown]
# (A) (Answer for A)

# %% [markdown]
# (B) (Answer for B)

# %% [markdown]
#  (C) (Answer for C
# )

# %% [markdown]
# ---
# # Report5C: Challenge on Chapter 6 or later
#
# If you have a time, make a challenge on chapter 6 or later of PyTorchADL.
#
# Make a compact summary below and tell what you learn on experience of the chapter.

# %% [markdown]
# (You can put text cells around here)

# %%
print ("You can put code cells too.")
# Out:
# You can put code cells too.

# %% [markdown]
# (You can put text cells around here)

# %% [markdown]
# ---
# #Report5X: Challenge on Paper with Code
#
# If you are an experinced student, challenge to run a project in [paper with code](https://paperswithcode.com/) on google colaboratory. Make a compact summary below for the installation procedure and show some evidence of the run. Write anything you find throught your challenge.

# %%
print ("You can put code cells too.")

# %% [markdown]
# (You can put text cells around here)

# %% [markdown]
# ---
# # Report submission
#
# The report template will be given in ipynb file. You should save it to your local google colaboratory folder and then edit it to fit your report.
#
# The report submission should be made at this cource (0ALE002) at https://manaba.tsukuba.ac.jp . Note that 0ALE005 is coupled with 0ALE002 (and 0AL5706) on manaba system.
#
# **File (main)**
#
# Download the ipynb to your local machine and then submit the file to the manaba.

# %% [markdown]
# ---
# Tools and Practices for Intelligent Interaction Systems A
# Master's and Docotal programs in intelligent and mechanical interaction systems, University of Tsukuba, Japan.
# KAMEDA Yoshinari, SHIBUYA Takeshi
#
# 知能システムツール演習a
# 知能機能システム学位プログラム (筑波大学大学院)
# 担当：亀田能成，澁谷長史
#
# 2022/08/08 ver.A.
